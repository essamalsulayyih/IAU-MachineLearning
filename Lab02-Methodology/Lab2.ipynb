# %%
import pandas as pd

df = pd.read_csv('IntegratedData.csv')

# %%
print("Dataset Shape:", df.shape)
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Dataset Shape: (935442, 17)
# Number of rows: 935442
# Number of columns: 17
#
# First 5 rows:
#          date   county    state  fips   cases  deaths  daily_cases  \
# 0  2021-01-01  autauga  alabama  1001  4239.0    50.0          0.0
# 1  2021-01-02  autauga  alabama  1001  4268.0    50.0         29.0
# 2  2021-01-03  autauga  alabama  1001  4305.0    50.0         37.0
# 3  2021-01-04  autauga  alabama  1001  4336.0    50.0         31.0
# 4  2021-01-05  autauga  alabama  1001  4546.0    50.0        210.0
#
#    daily_deaths  day_of_week  is_weekend  is_holiday  retail_recreation  \
# 0           0.0          4.0         0.0         1.0              -46.0
# 1           0.0          5.0         1.0         0.0              -10.0
# 2           0.0          6.0         1.0         0.0              -12.0
# 3           0.0          0.0         0.0         0.0                4.0
# 4           0.0          1.0         0.0         0.0                2.0
#
# ...

# %%
print("\nColumn names:")
print(df.columns)

print("\nData types:")
print(df.dtypes)

print("\nDataset info:")
df.info()
# Out:
# Column names:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths', 'daily_cases',
#        'daily_deaths', 'day_of_week', 'is_weekend', 'is_holiday',
#        'retail_recreation', 'grocery_pharmacy', 'parks', 'transit',
#        'workplaces', 'residential'],
#       dtype='str')
#
# Data types:
# date                     str
# county                   str
# state                    str
# fips                   int64
# cases                float64
# deaths               float64
# daily_cases          float64
# daily_deaths         float64
# day_of_week          float64
# is_weekend           float64
# is_holiday           float64
# retail_recreation    float64
# grocery_pharmacy     float64
# parks                float64
# transit              float64
# workplaces           float64
# residential          float64
# dtype: object
#
# Dataset info:
# <class 'pandas.DataFrame'>
# RangeIndex: 935442 entries, 0 to 935441
# Data columns (total 17 columns):
# ...

# %% [markdown]
# Problem Description: Predicting the number of daily new COVID-19 cases in US counties based on human mobility metrics like visits to retail, workplaces, and residential areas.  ML Category: Regression (since the target is a continuous numerical value). Target Variable: daily_cases
# Goal: To understand how changes in community movement patterns influence the spread of the virus.
