# %%
import pandas as pd

df = pd.read_csv('house_prices.csv') 

print(f"Dataset Shape: {df.shape}") 

print("\nFirst 5 rows:")
display(df.head()) [cite: 160]

print("\nDataset Info:")
df.info()

# %% [markdown]
# Problem Description: Predicting house prices in India based on features like location, area, and description.  Problem Type: This is a Regression problem because we are predicting a continuous numerical value.
