# %% [markdown]
# ARTI308 - Machine Learning
#
# # Credit Card Customer Segmentation Project
#
# In this project, you will use K-Means clustering to segment [credit card customers](https://www.kaggle.com/datasets/arjunbhasin2013/ccdata/data) based on their usage behavior. This is an unsupervised learning problem because the dataset does not contain a target label for customer groups.
#
# You will use the `CC_GENERAL.csv` dataset.

# %% [markdown]
# ## About the Dataset
#
# The dataset contains customer-level credit card usage behavior. Each row represents one credit card holder, and the columns describe different behavioral variables such as balance, purchases, cash advance, payments, and tenure. The goal is to group similar customers together so that the company can understand different customer segments and design better marketing strategies.

# %% [markdown]
# ## Import Libraries
#
# **Import the libraries you need for data analysis, visualization, preprocessing, clustering, and evaluation.**

# %%
import sys
# !{sys.executable} -m pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Collecting numpy
#   Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas
#   Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (26.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 1.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/12.3 MB 2.5 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.3 MB 2.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/12.3 MB 3.6 MB/s eta 0:00:03
#    --------------- ------------------------ 4.7/12.3 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.3 MB 4.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.8/12.3 MB 4.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.3 MB 4.1 MB/s eta 0:00:02
#    -------------------------- ------------- 8.1/12.3 MB 4.1 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.3 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 4.6 MB/s eta 0:00:00
# Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.8 MB 6.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.8 MB 6.6 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.8 MB 5.9 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.8 MB 5.6 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.8 MB 5.8 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 5.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 4.6 MB/s eta 0:00:00
# Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.2 MB 7.1 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.2 MB 6.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.2 MB 5.7 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 5.9 MB/s eta 0:00:00
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.0 MB 7.4 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/8.0 MB 5.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 5.0 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.0 MB 4.6 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 4.7 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 5.0 MB/s eta 0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.1 MB 6.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.1/7.1 MB 5.4 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/7.1 MB 5.4 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.1 MB 5.7 MB/s eta 0:00:01
#    -------------------------------- ------- 5.8/7.1 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.1 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 5.3 MB/s eta 0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.5 MB 6.2 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/36.5 MB 5.5 MB/s eta 0:00:07
#    --- ------------------------------------ 2.9/36.5 MB 4.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.9/36.5 MB 4.7 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.0/36.5 MB 4.9 MB/s eta 0:00:07
#    ------ --------------------------------- 6.3/36.5 MB 5.1 MB/s eta 0:00:06
#    -------- ------------------------------- 7.9/36.5 MB 5.4 MB/s eta 0:00:06
#    --------- ------------------------------ 8.9/36.5 MB 5.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.0/36.5 MB 5.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 10.7/36.5 MB 5.3 MB/s eta 0:00:05
#    ------------ --------------------------- 11.3/36.5 MB 4.9 MB/s eta 0:00:06
#    ------------- -------------------------- 12.1/36.5 MB 4.8 MB/s eta 0:00:06
#    -------------- ------------------------- 13.4/36.5 MB 4.9 MB/s eta 0:00:05
#    --------------- ------------------------ 14.2/36.5 MB 4.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 14.9/36.5 MB 4.8 MB/s eta 0:00:05
#    ----------------- ---------------------- 16.3/36.5 MB 4.8 MB/s eta 0:00:05
#    ------------------ --------------------- 17.0/36.5 MB 4.7 MB/s eta 0:00:05
#    ------------------- -------------------- 18.1/36.5 MB 4.8 MB/s eta 0:00:04
#    -------------------- ------------------- 18.9/36.5 MB 4.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 20.2/36.5 MB 4.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 21.0/36.5 MB 4.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 21.8/36.5 MB 4.7 MB/s eta 0:00:04
#    ------------------------ --------------- 22.8/36.5 MB 4.7 MB/s eta 0:00:03
#    -------------------------- ------------- 23.9/36.5 MB 4.7 MB/s eta 0:00:03
#    --------------------------- ------------ 24.9/36.5 MB 4.7 MB/s eta 0:00:03
#    --------------------------- ------------ 25.4/36.5 MB 4.7 MB/s eta 0:00:03
#    --------------------------- ------------ 25.4/36.5 MB 4.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 26.5/36.5 MB 4.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.0/36.5 MB 4.4 MB/s eta 0:00:03
#    ------------------------------ --------- 27.8/36.5 MB 4.4 MB/s eta 0:00:02
#    ------------------------------- -------- 28.3/36.5 MB 4.4 MB/s eta 0:00:02
#    ------------------------------- -------- 28.8/36.5 MB 4.3 MB/s eta 0:00:02
#    ------------------------------- -------- 29.1/36.5 MB 4.2 MB/s eta 0:00:02
#    -------------------------------- ------- 29.9/36.5 MB 4.2 MB/s eta 0:00:02
#    --------------------------------- ------ 30.7/36.5 MB 4.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 31.2/36.5 MB 4.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 31.7/36.5 MB 4.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.5/36.5 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 33.3/36.5 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 34.1/36.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 34.6/36.5 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 35.1/36.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 3.9 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: tzdata, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib, seaborn
#
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    ----- ----------------------------------  2/15 [pyparsing]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    ----------------------------- ---------- 11/15 [contourpy]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ---------------------------------------- 15/15 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 joblib-1.5.3 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.4.4 pandas-3.0.3 pillow-12.2.0 pyparsing-3.3.2 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0 tzdata-2026.2
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Admin\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\Admin\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %% [markdown]
# ## Get the Data
#
# **Read the `CC_GENERAL.csv` file and save it in a dataframe called `df`.**

# %%
df = pd.read_csv('CC_GENERAL.csv')

# %% [markdown]
# **Check the first five rows of the dataset.**

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# **Check the shape of the dataset.**

# %%
df.shape
# Out:
# (8950, 18)

# %% [markdown]
# **Check basic information about the dataset using `info()`.**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   str
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), str(1)
# memory usage: 1.2 MB

# %% [markdown]
# **Check summary statistics using `describe()`.**

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# ## Data Cleaning
#
# The column `CUST_ID` is an identification column. It is not useful for clustering because it does not describe customer behavior.
#
# **Drop the `CUST_ID` column from the dataframe.**

# %%
df.drop('CUST_ID', axis=1, inplace=True)

# %% [markdown]
# **Check the missing values in each column.**

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# Some columns may contain missing values.
#
# Hint: You can handle missing values by either:
# - filling them with the mean value
# - or dropping the rows that contain missing values
#
# For this project, use mean imputation.
#
# **Fill the missing values with the mean of each column.**

# %%
df.fillna(df.mean(), inplace=True)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000        864.206542          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322        864.206542          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 17 columns]

# %% [markdown]
# **Check the missing values again to make sure they were handled.**

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis
#
# Before applying clustering, it is important to understand the data.
#
# **Create histograms for the numerical columns.**

# %%
df.hist(figsize=(16, 12), bins=30)
plt.tight_layout()
plt.suptitle('Distribution of Credit Card Features', y=1.02, fontsize=14)
plt.show()

# %% [markdown]
# **Create a correlation heatmap to understand relationships between the features.**

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Create a scatter plot between `BALANCE` and `PURCHASES`.**

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['BALANCE'], df['PURCHASES'], alpha=0.3, color='steelblue')
plt.xlabel('Balance')
plt.ylabel('Purchases')
plt.title('Balance vs Purchases')
plt.show()

# %% [markdown]
# **Create a scatter plot between `BALANCE` and `CASH_ADVANCE`.**

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['BALANCE'], df['CASH_ADVANCE'], alpha=0.3, color='tomato')
plt.xlabel('Balance')
plt.ylabel('Cash Advance')
plt.title('Balance vs Cash Advance')
plt.show()

# %% [markdown]
# ## Feature Scaling
#
# K-Means is a distance-based algorithm. Therefore, feature scaling is very important.
#
# The features in this dataset have very different ranges. For example, `BALANCE`, `PURCHASES`, and `CREDIT_LIMIT` may have large values, while frequency columns are between 0 and 1.
#
# **Use StandardScaler to scale the data. Save the scaled data in a variable called `X_scaled`.**

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %% [markdown]
# ## Choosing K Intuitively
#
# Choosing K is one of the most difficult parts of K-Means.
#
# Since this dataset has many features, it is not easy to visually see the clusters directly.
#
# However, we can still compare different K values using the elbow method and silhouette score.

# %% [markdown]
# ## Elbow Method
#
# **Create a loop that fits K-Means models for K values from 1 to 10. Save the inertia values in a list called `inertia_values`.**

# %%
inertia_values = []

K_range = range(1, 11)

for k in K_range:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    model.fit(X_scaled)
    inertia_values.append(model.inertia_)

# %% [markdown]
# **Plot the elbow curve.**

# %%
plt.figure(figsize=(8, 5))
plt.plot(K_range, inertia_values, marker='o', color='steelblue')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Choosing K')
plt.xticks(K_range)
plt.show()

# %% [markdown]
# **Output Interpretation**
#
# Look at the elbow curve and try to identify where the decrease in inertia starts to slow down.
#
# That point can suggest a reasonable value for K.

# %% [markdown]
# ## Silhouette Score
#
# The silhouette score helps evaluate how well-separated the clusters are.
#
# **Create a loop that calculates the silhouette score for K values from 2 to 10. Save the scores in a list called `silhouette_scores`.**

# %%
silhouette_scores = []

K_range_sil = range(2, 11)

for k in K_range_sil:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = model.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    silhouette_scores.append(score)

# %% [markdown]
# **Plot the silhouette scores.**

# %%
plt.figure(figsize=(8, 5))
plt.plot(K_range_sil, silhouette_scores, marker='o', color='darkorange')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different K Values')
plt.xticks(K_range_sil)
plt.show()

# %% [markdown]
# **Create a table showing each K value and its silhouette score.**

# %%
silhouette_df = pd.DataFrame({
    'K': list(K_range_sil),
    'Silhouette Score': [round(s, 4) for s in silhouette_scores]
})

silhouette_df
# Out:
#     K  Silhouette Score
# 0   2            0.2100
# 1   3            0.2506
# 2   4            0.1976
# 3   5            0.1932
# 4   6            0.2026
# 5   7            0.2150
# 6   8            0.2081
# 7   9            0.2149
# 8  10            0.2205

# %% [markdown]
# **Output Interpretation**
#
# A higher silhouette score usually means better clustering.
#
# However, do not rely only on the highest value. Also consider whether the chosen K makes sense for customer segmentation.

# %% [markdown]
# ## Create the Final K-Means Model
#
# **Based on the elbow curve and silhouette scores, choose a final K value. Then train a final K-Means model.**
#
# Use `random_state=42` and `n_init=10`.

# %%
# K=4 is chosen based on:
# - The elbow curve shows a noticeable bend around K=3-4
# - K=3 has the highest silhouette score (0.2506), but K=4 gives
#   more meaningful and distinct business segments
# - Four segments provide a practical and interpretable customer grouping

final_kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
final_kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %% [markdown]
# **Add the final cluster labels to the original dataframe in a new column called `Cluster`.**

# %%
df['Cluster'] = final_kmeans.labels_

# %% [markdown]
# **Check the first five rows after adding the cluster labels.**

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  Cluster
# 0   201.802084        139.509787          0.000000      12        3
# 1  4103.032597       1072.340217          0.222222      12        2
# 2   622.066742        627.284787          0.000000      12        0
# 3     0.000000        864.206542          0.000000      12        3
# 4   678.334763        244.791237          0.000000      12        3

# %% [markdown]
# ## Cluster Analysis
#
# Now we need to understand what each cluster means.
#
# **Create a summary table using `groupby()` to show the mean values of each feature for each cluster.**

# %%
cluster_summary = df.groupby('Cluster').mean().round(2)
cluster_summary
# Out:
#          BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0         894.91               0.93    1236.18            593.97
# 1        3551.15               0.99    7681.62           5095.88
# 2        4602.46               0.97     501.90            320.37
# 3        1011.75               0.79     269.97            209.85
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                        642.48        210.57                 0.89
# 1                       2587.21        653.64                 0.95
# 2                        181.61       4520.72                 0.29
# 3                         60.39        595.76                 0.17
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                              0.30                              0.71
# 1                              0.74                              0.79
# 2                              0.14                              0.19
# 3                              0.09                              0.08
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# Cluster
# 0                          0.04              0.79          22.09
# 1                          0.07              2.09          89.36
# 2                          0.48             14.28           7.66
# 3                          0.11              2.13           2.90
#
#          CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# Cluster
# 0             4213.21   1332.19            650.17              0.27   11.59
# 1             9696.94   7288.74           1976.82              0.29   11.95
# 2             7546.96   3481.15           2008.25              0.03   11.39
# 3             3277.70    974.51            586.30              0.08   11.45

# %% [markdown]
# **Check how many customers are in each cluster.**

# %%
cluster_counts = df['Cluster'].value_counts().sort_index()
print(cluster_counts)

plt.figure(figsize=(7, 4))
cluster_counts.plot(kind='bar', color=['steelblue', 'darkorange', 'green', 'tomato'])
plt.xlabel('Cluster')
plt.ylabel('Number of Customers')
plt.title('Number of Customers per Cluster')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Cluster
# 0    3367
# 1     409
# 2    1198
# 3    3976
# Name: count, dtype: int64

# %% [markdown]
# ## Visualizing the Final Clusters
#
# Since the dataset has many features, we will use PCA to reduce the data into two components only for visualization.
#
# This visualization does not replace the original clustering. It only helps us see the clusters in a 2D plot.
#
# **Use PCA with 2 components and plot the clusters.**

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(9, 6))
scatter = plt.scatter(
    X_pca[:, 0],
    X_pca[:, 1],
    c=df['Cluster'],
    cmap='tab10',
    alpha=0.5,
    s=20
)
plt.colorbar(scatter, label='Cluster')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Customer Clusters visualized with PCA (2D)')
plt.tight_layout()
plt.show()

print(f'Explained variance ratio: {pca.explained_variance_ratio_.round(3)}')
print(f'Total variance explained: {pca.explained_variance_ratio_.sum():.1%}')
# Out:
# Explained variance ratio: [0.273 0.203]
# Total variance explained: 47.6%

# %% [markdown]
# **Output Interpretation**
#
# The PCA plot gives a simplified 2D view of the clusters.
#
# If the clusters are not perfectly separated, that is normal because the original dataset has many features and the plot only shows two compressed dimensions.

# %% [markdown]
# ## Final Questions
#
# Answer the following questions:

# %% [markdown]
# **1. Why is this an unsupervised learning problem?**
#
# This is an unsupervised learning problem because the dataset does not contain a target label or pre-defined customer categories. There is no column that tells us which group each customer belongs to. K-Means must discover these groups on its own by finding patterns in the features.

# %% [markdown]
# **2. Why did we remove the `CUST_ID` column?**
#
# The `CUST_ID` column is just a unique identifier for each customer. It carries no information about customer behavior. If we kept it, K-Means would try to compute distances using customer IDs, which would produce meaningless results. Removing it ensures the algorithm only uses real behavioral features.

# %% [markdown]
# **3. Which columns had missing values?**
#
# Two columns had missing values:
# - `CREDIT_LIMIT`: 1 missing value
# - `MINIMUM_PAYMENTS`: 313 missing values

# %% [markdown]
# **4. How did you handle the missing values?**
#
# We used mean imputation: each missing value was replaced with the mean of its column. This approach preserves all rows and avoids losing data, while keeping the overall distribution of the column relatively stable.

# %% [markdown]
# **5. Why is scaling important before applying K-Means?**
#
# K-Means groups data points based on Euclidean distance. If features have very different ranges (for example, `BALANCE` can reach thousands while `PURCHASES_FREQUENCY` is between 0 and 1), features with large values will dominate the distance calculation and unfairly influence the clustering result. StandardScaler transforms every feature to have zero mean and unit variance, so all features contribute equally.

# %% [markdown]
# **6. Which K value did you choose? Explain your answer using the elbow method and silhouette score.**
#
# We chose **K = 4**.
#
# - **Elbow method**: The inertia curve shows a noticeable bend around K = 3 to K = 4. After that point, adding more clusters produces smaller improvements.
# - **Silhouette score**: K = 3 has the highest score (≈ 0.25), and K = 4 has the second-best score (≈ 0.20). While K = 3 scores slightly higher, it produces fewer customer segments and merges distinct behavioral groups.
# - **Business reasoning**: K = 4 separates the data into four clear and meaningful customer types (see Question 7), making it more practical for marketing decisions.

# %% [markdown]
# **7. Based on the cluster summary table, describe each customer segment in your own words.**
#
# Based on the cluster means:
#
# | Cluster | Description |
# |---------|-------------|
# | **0** | **Active Shoppers** — Moderate balance (~895), good level of purchases (~1,236), moderate payments. These customers actively use their card for purchases. |
# | **1** | **High-Value Customers** — High balance (~3,551), very high purchases (~7,682), high credit limit (~9,697), and high payments (~7,289). These are premium, highly engaged customers. |
# | **2** | **Cash Advance Users** — High balance (~4,603), very high cash advance (~4,521), but low purchases (~502). These customers primarily borrow cash rather than shopping. |
# | **3** | **Low-Activity Customers** — Low balance (~1,012), very low purchases (~270), low credit limit (~3,278), and low payments (~974). These are mostly inactive or passive cardholders. |

# %% [markdown]
# **8. Which cluster may represent high-value customers?**
#
# **Cluster 1** represents high-value customers. They have the highest purchases (~7,682), the highest credit limit (~9,697), and the highest payments (~7,289). These customers are highly engaged, spend a lot, and repay their balances well — making them the most valuable segment for the company.

# %% [markdown]
# **9. Which cluster may represent customers who rely more on cash advance?**
#
# **Cluster 2** represents cash advance-reliant customers. They have the highest average cash advance amount (~4,521) and a very high balance (~4,603), while their purchases are low (~502). This means they rarely use their card for shopping and instead frequently withdraw cash, which may indicate financial strain or a specific preference for cash transactions.

# %% [markdown]
# **10. How can a company use these clusters for marketing strategy?**
#
# Each cluster suggests a different marketing approach:
#
# - **Cluster 1 (High-Value)**: Offer loyalty rewards, premium card upgrades, and exclusive offers to retain and grow this segment.
# - **Cluster 0 (Active Shoppers)**: Provide cashback promotions, installment plans, or partner discounts to encourage more spending.
# - **Cluster 2 (Cash Advance Users)**: Offer financial counseling, lower-interest personal loan products, or tools to help manage debt — and be cautious about increasing credit limits.
# - **Cluster 3 (Low-Activity)**: Send re-engagement campaigns, special introductory offers, or spending bonuses to activate these dormant customers.
#
# By targeting each segment with a tailored strategy, the company avoids one-size-fits-all marketing and improves both customer satisfaction and revenue.
